# %% [markdown]
# ## Intro to Dataframes
#
# A DataFrame is a table. It contains an array of individual entries, each of which has a certain value. Each entry corresponds to a row (or record) and a column.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Toy example 1: DataFrame from a matrix

# %%
toy_matrix = [[1,2,3],
              [4,5,6],
              [7,8,9],
              [1,1,2],
              [0,0,9],
              [0,0,10]
             ]
df = pd.DataFrame(toy_matrix, columns=["A", "B", "C"],index=["a","b","c","d","e","f"],dtype=int)

# %%
display(df)
# Out:
#    A  B   C
# a  1  2   3
# b  4  5   6
# c  7  8   9
# d  1  1   2
# e  0  0   9
# f  0  0  10

# %%
df
# Out:
#    A  B   C
# a  1  2   3
# b  4  5   6
# c  7  8   9
# d  1  1   2
# e  0  0   9
# f  0  0  10

# %%
print(df)
# Out:
#    A  B   C
# a  1  2   3
# b  4  5   6
# c  7  8   9
# d  1  1   2
# e  0  0   9
# f  0  0  10

# %%
df.head(3)
# Out:
#    A  B  C
# a  1  2  3
# b  4  5  6
# c  7  8  9

# %%
df.tail(2)
# Out:
#    A  B   C
# e  0  0   9
# f  0  0  10

# %%
df.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
# df.rows does NOT exist
# use df.index instead
df.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, a to f
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       6 non-null      int64
#  1   B       6 non-null      int64
#  2   C       6 non-null      int64
# dtypes: int64(3)
# memory usage: 192.0+ bytes

# %%
df.describe()
# x% percentile is the value below which x% of the data points fall
# Out:
#               A         B          C
# count  6.000000  6.000000   6.000000
# mean   2.166667  2.666667   6.500000
# std    2.786874  3.204164   3.391165
# min    0.000000  0.000000   2.000000
# 25%    0.250000  0.250000   3.750000
# 50%    1.000000  1.500000   7.500000
# 75%    3.250000  4.250000   9.000000
# max    7.000000  8.000000  10.000000

# %%
df
# Out:
#    A  B   C
# a  1  2   3
# b  4  5   6
# c  7  8   9
# d  1  1   2
# e  0  0   9
# f  0  0  10

# %%
df.nunique()
# Out:
# A    4
# B    5
# C    5
# dtype: int64

# %%
df['B']
# Out:
# a    2
# b    5
# c    8
# d    1
# e    0
# f    0
# Name: B, dtype: int64

# %%
df[['A','B']]
# Out:
#    A  B
# a  1  2
# b  4  5
# c  7  8
# d  1  1
# e  0  0
# f  0  0

# %%
df['B'].unique()
# Out:
# array([2, 5, 8, 1, 0])

# %%
df['B'].nunique()
# Out:
# 5

# %%
df.shape
# Out:
# (6, 3)

# %%
df.size
# Out:
# 18

# %% [markdown]
# ### Toy example 2: DataFrame from a dictionary

# %%
pd.DataFrame({'Yes': [30, 21, 30], 'No': [131, 2, 34], 'Maybe' : [1,'nan',100]})
# Out:
#    Yes   No Maybe
# 0   30  131     1
# 1   21    2   nan
# 2   30   34   100

# %%
data = {
    'Date': ['2024-05-01', '2024-05-01', '2024-05-01', '2024-05-02', '2024-05-02', '2024-05-03', '2024-05-03', '2024-05-03'],
    'Item': ['Apple', 'Banana', 'Orange', 'Apple', 'Banana', 'Orange', 'Apple', 'Orange'],
    'Units Sold': [30, 21, 15, 40, 34, 20, 45, 25],
    'Price Per Unit': [1.0, 0.5, 0.75, 1.0, 0.5, 0.75, 1.0, 0.75],
    'Salesperson': ['John', 'John', 'John', 'Alice', 'Alice', 'John', 'Alice', 'John']
}

df2 = pd.DataFrame(data)

# Display the DataFrame
df2
# Out:
#          Date    Item  Units Sold  Price Per Unit Salesperson
# 0  2024-05-01   Apple          30            1.00        John
# 1  2024-05-01  Banana          21            0.50        John
# 2  2024-05-01  Orange          15            0.75        John
# 3  2024-05-02   Apple          40            1.00       Alice
# 4  2024-05-02  Banana          34            0.50       Alice
# 5  2024-05-03  Orange          20            0.75        John
# 6  2024-05-03   Apple          45            1.00       Alice
# 7  2024-05-03  Orange          25            0.75        John

# %% [markdown]
# ## Loading in Dataframes from Files

# %%
coffee = pd.read_csv('./data/coffee.csv')

# %%
results = pd.read_csv('./data/results.csv')
bios = pd.read_csv('./data/bios.csv')

# %%
url = "https://people.sc.fsu.edu/~jburkardt/data/csv/airtravel.csv"
df = pd.read_csv(url)
df
# Out:
#    Month   "1958"   "1959"   "1960"
# 0    JAN      340      360      417
# 1    FEB      318      342      391
# 2    MAR      362      406      419
# 3    APR      348      396      461
# 4    MAY      363      420      472
# 5    JUN      435      472      535
# 6    JUL      491      548      622
# 7    AUG      505      559      606
# 8    SEP      404      463      508
# 9    OCT      359      407      461
# 10   NOV      310      362      390
# 11   DEC      337      405      432

# %%
## To read an excel spreadsheet
# You need to 
# pip install openpyxl
olympics_data = pd.read_excel('./data/olympics-data.xlsx', sheet_name="results")

# %% [markdown]
# ## Accessing Data with Pandas

# %%
print(coffee)
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
display(coffee)
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
coffee.tail(10)
# Out:
#           Day Coffee Type  Units Sold
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.sample(5)
# Out:
#           Day Coffee Type  Units Sold
# 7    Thursday       Latte          30
# 4   Wednesday    Espresso          35
# 10   Saturday    Espresso          45
# 9      Friday       Latte          35
# 1      Monday       Latte          15

# %%
coffee.sample(5, random_state=42) # Pass in random_state to make deterministic
# Out:
#           Day Coffee Type  Units Sold
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 0      Monday    Espresso          25
# 12     Sunday    Espresso          45
# 5   Wednesday       Latte          25

# %% [markdown]
# ## `loc` & `iloc`
# Usage: `loc[rows]` or `loc[rows, columns]`
#
# Usage: `iloc[rows]` or `iloc[rows, columns]`

# %%
coffee.loc[2]
# Out:
# Day             Tuesday
# Coffee Type    Espresso
# Units Sold           30
# Name: 2, dtype: object

# %%
coffee.loc[[2]]
# Out:
#        Day Coffee Type  Units Sold
# 2  Tuesday    Espresso          30

# %%
coffee.loc[[0,1,5]]
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 5  Wednesday       Latte          25

# %%
coffee.loc[-5:]
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.loc[5:9, ["Day", "Units Sold"]]
# Out:
#          Day  Units Sold
# 5  Wednesday          25
# 6   Thursday          40
# 7   Thursday          30
# 8     Friday          45
# 9     Friday          35

# %%
coffee.iloc[5:9, [0,2]]
# Out:
#          Day  Units Sold
# 5  Wednesday          25
# 6   Thursday          40
# 7   Thursday          30
# 8     Friday          45

# %% [markdown]
# #### Setting the index for `loc`

# %%
coffee.index = coffee["Day"]

# %%
coffee.set_index("Day")
# Out:
#           Coffee Type  Units Sold
# Day
# Monday       Espresso          25
# Monday          Latte          15
# Tuesday      Espresso          30
# Tuesday         Latte          20
# Wednesday    Espresso          35
# Wednesday       Latte          25
# Thursday     Espresso          40
# Thursday        Latte          30
# Friday       Espresso          45
# Friday          Latte          35
# Saturday     Espresso          45
# Saturday        Latte          35
# Sunday       Espresso          45
# Sunday          Latte          35

# %%
coffee.loc["Monday":"Thursday",['Day', 'Coffee Type']]
# Out:
#                  Day Coffee Type
# Day
# Monday        Monday    Espresso
# Monday        Monday       Latte
# Tuesday      Tuesday    Espresso
# Tuesday      Tuesday       Latte
# Wednesday  Wednesday    Espresso
# Wednesday  Wednesday       Latte
# Thursday    Thursday    Espresso
# Thursday    Thursday       Latte

# %%
coffee.reset_index(drop=True, inplace=True)
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %% [markdown]
# ## Setting Values

# %%
coffee = pd.read_csv('./data/coffee.csv')

# %%
coffee.loc[1:3, "Units Sold"] = 10

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          10
# 2     Tuesday    Espresso          10
# 3     Tuesday       Latte          10
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %% [markdown]
# #### Optimized way to get single values (`.at` & `.iat`)

# %%
coffee.at[0,"Units Sold"]
# Out:
# np.int64(25)

# %%
coffee.iat[3,1]
# Out:
# 'Latte'

# %% [markdown]
# #### Getting Columns

# %%
coffee.Day
# Out:
# 0        Monday
# 1        Monday
# 2       Tuesday
# 3       Tuesday
# 4     Wednesday
# 5     Wednesday
# 6      Thursday
# 7      Thursday
# 8        Friday
# 9        Friday
# 10     Saturday
# 11     Saturday
# 12       Sunday
# 13       Sunday
# Name: Day, dtype: object

# %%
coffee["Day"]
# Out:
# 0        Monday
# 1        Monday
# 2       Tuesday
# 3       Tuesday
# 4     Wednesday
# 5     Wednesday
# 6      Thursday
# 7      Thursday
# 8        Friday
# 9        Friday
# 10     Saturday
# 11     Saturday
# 12       Sunday
# 13       Sunday
# Name: Day, dtype: object

# %% [markdown]
# #### Sort Values

# %%
coffee.sort_values(["Units Sold"], ascending=False)
# Out:
#           Day Coffee Type  Units Sold
# 10   Saturday    Espresso          45
# 8      Friday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 4   Wednesday    Espresso          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 9      Friday       Latte          35
# 7    Thursday       Latte          30
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 2     Tuesday    Espresso          10
# 1      Monday       Latte          10
# 3     Tuesday       Latte          10

# %%
coffee.sort_values(["Units Sold", "Coffee Type"], ascending=[0,1])
# Out:
#           Day Coffee Type  Units Sold
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 7    Thursday       Latte          30
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 2     Tuesday    Espresso          10
# 1      Monday       Latte          10
# 3     Tuesday       Latte          10

# %% [markdown]
# #### Iterate over dataframe with `for` loop

# %%
for index, row in coffee.iterrows():
    print(index)
    print(row)
    print("Coffee Type of Row:", row["Coffee Type"])
# Out:
# 0
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# Name: 0, dtype: object
# Coffee Type of Row: Espresso
# 1
# Day            Monday
# Coffee Type     Latte
# Units Sold         10
# Name: 1, dtype: object
# Coffee Type of Row: Latte
# 2
# Day             Tuesday
# Coffee Type    Espresso
# Units Sold           10
# Name: 2, dtype: object
# Coffee Type of Row: Espresso
# 3
# Day            Tuesday
# Coffee Type      Latte
# Units Sold          10
# Name: 3, dtype: object
# Coffee Type of Row: Latte
# 4
# Day            Wednesday
# Coffee Type     Espresso
# Units Sold            35
# Name: 4, dtype: object
# Coffee Type of Row: Espresso
# 5
# Day            Wednesday
# Coffee Type        Latte
# Units Sold            25
# Name: 5, dtype: object
# Coffee Type of Row: Latte
# 6
# Day            Thursday
# Coffee Type    Espresso
# Units Sold           40
# Name: 6, dtype: object
# Coffee Type of Row: Espresso
# 7
# Day            Thursday
# Coffee Type       Latte
# Units Sold           30
# Name: 7, dtype: object
# Coffee Type of Row: Latte
# 8
# Day              Friday
# Coffee Type    Espresso
# Units Sold           45
# Name: 8, dtype: object
# Coffee Type of Row: Espresso
# 9
# Day            Friday
# Coffee Type     Latte
# Units Sold         35
# Name: 9, dtype: object
# Coffee Type of Row: Latte
# 10
# Day            Saturday
# Coffee Type    Espresso
# Units Sold           45
# Name: 10, dtype: object
# Coffee Type of Row: Espresso
# 11
# Day            Saturday
# Coffee Type       Latte
# Units Sold           35
# Name: 11, dtype: object
# Coffee Type of Row: Latte
# 12
# Day              Sunday
# Coffee Type    Espresso
# Units Sold           45
# Name: 12, dtype: object
# Coffee Type of Row: Espresso
# 13
# Day            Sunday
# Coffee Type     Latte
# Units Sold         35
# Name: 13, dtype: object
# Coffee Type of Row: Latte

# %% [markdown]
# ## Filtering Data

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios.loc[bios["height_cm"] > 220]
# Out:
#         athlete_id             name   born_date       born_city  \
# 5673          5696   Gunther Behnke  1963-01-19      Leverkusen
# 5781          5804   Tommy Burleson  1952-02-24       Crossnore
# 6978          7013  Arvydas Sabonis  1964-12-19          Kaunas
# 89070        89782         Yao Ming  1980-09-12  Xuhui District
# 89075        89787   Roberto Dueñas  1975-11-01          Madrid
# 120266      122147     Zhang Zhaoxu  1987-11-18         Binzhou
#
#                 born_region born_country                         NOC  \
# 5673    Nordrhein-Westfalen          GER                     Germany
# 5781         North Carolina          USA               United States
# 6978                 Kaunas          LTU      Lithuania Soviet Union
# 89070              Shanghai          CHN  People's Republic of China
# 89075                Madrid          ESP                       Spain
# 120266             Shandong          CHN  People's Republic of China
#
#         height_cm  weight_kg died_date
# 5673        221.0      114.0       NaN
# 5781        223.0      102.0       NaN
# 6978        223.0      122.0       NaN
# 89070       226.0      141.0       NaN
# 89075       221.0      137.0       NaN
# 120266      221.0      110.0       NaN

# %%
bios.loc[bios["height_cm"] > 220, ["name", "height_cm"]]
# Out:
#                    name  height_cm
# 5673     Gunther Behnke      221.0
# 5781     Tommy Burleson      223.0
# 6978    Arvydas Sabonis      223.0
# 89070          Yao Ming      226.0
# 89075    Roberto Dueñas      221.0
# 120266     Zhang Zhaoxu      221.0

# %% [markdown]
# #### Short-hand syntax (without .loc)

# %%
bios[bios['height_cm'] > 220][["name","height_cm"]]
# Out:
#                    name  height_cm
# 5673     Gunther Behnke      221.0
# 5781     Tommy Burleson      223.0
# 6978    Arvydas Sabonis      223.0
# 89070          Yao Ming      226.0
# 89075    Roberto Dueñas      221.0
# 120266     Zhang Zhaoxu      221.0

# %% [markdown]
# #### Multiple filter conditions

# %%
bios[(bios['height_cm'] > 220) & (bios['born_country']=='USA')]
# Out:
#       athlete_id            name   born_date  born_city     born_region  \
# 5781        5804  Tommy Burleson  1952-02-24  Crossnore  North Carolina
#
#      born_country            NOC  height_cm  weight_kg died_date
# 5781          USA  United States      223.0      102.0       NaN

# %% [markdown]
# #### Filter by string conditions

# %%
bios[bios['name'].str.contains("Pan", case=False) ]
# Out:
#         athlete_id                      name   born_date        born_city  \
# 179            180     Pantelis Papadopoulos  1902-01-01              NaN
# 277            278    Deepankar Bhattacharya  1972-02-01              NaN
# 1090          1097          Stefan Panayotov  1941-07-26           Sliven
# 1091          1098              Kiril Pandov  1943-05-03              NaN
# 1413          1420              Sonja Pannen  1968-11-15           Leiden
# ...            ...                       ...         ...              ...
# 144131      147804  Anastasios Papanastasiou  1967-08-07  Athina (Athens)
# 144170      147848             Sascha Stepan  1998-01-11           Schwaz
# 145064      148776        Veronika Stepanova  2001-01-04         Yelizovo
# 145082      148794      Yeseniya Pantyukhova  2005-08-04        Yaroslavl
# 145094      148807      Aleksandra Stepanova  1995-08-19              NaN
#
#            born_region born_country          NOC  height_cm  weight_kg  \
# 179                NaN          NaN       Greece        NaN        NaN
# 277                NaN          NaN        India      178.0       68.0
# 1090            Sliven          BUL     Bulgaria      158.0       51.0
# 1091               NaN          NaN     Bulgaria      196.0       90.0
# 1413      Zuid-Holland          NED  Netherlands        NaN        NaN
# ...                ...          ...          ...        ...        ...
# 144131          Attiki          GRE       Greece      186.0       87.0
# 144170           Tirol          AUT      Austria        NaN        NaN
# 145064  Kamchatka Kray          RUS          ROC        NaN        NaN
# 145082       Yaroslavl          RUS          ROC        NaN        NaN
# 145094             NaN          NaN          ROC        NaN        NaN
#
#          died_date
# 179     1987-01-01
# 277            NaN
# 1090    2003-11-24
# 1091    2013-01-01
# 1413           NaN
# ...            ...
# 144131         NaN
# 144170         NaN
# 145064         NaN
# 145082         NaN
# 145094         NaN
#
# [538 rows x 10 columns]

# %%
# Regex syntax
bios[bios['name'].str.contains('Carl|John', case=False)]
# Out:
#         athlete_id                   name   born_date           born_city  \
# 78              79       John Pius Boland  1870-09-16              Dublin
# 111            112             Carl Prean  1967-08-20             Newport
# 159            160         Carl-Uwe Steeb  1967-09-01               Aalen
# 375            376          John McDonald  1965-05-28             Halifax
# 423            424    Juan Carlos Holgado  1968-04-16            Dierdorf
# ...            ...                    ...         ...                 ...
# 144747      148448           Carlos Mäder  1978-10-23          Cape Coast
# 145371      149094        Carly Margulies  1997-12-24      Salt Lake City
# 145461      149188           Kent Johnson  2002-10-18          Port Moody
# 145488      149215           Shakeel John  2001-07-30          Mount Hope
# 145492      149219  Carlos García-Ordóñez  1927-04-24  La Habana (Havana)
#
#                 born_region born_country                   NOC  height_cm  \
# 78                   Dublin          IRL         Great Britain        NaN
# 111                 England          GBR         Great Britain      185.0
# 159       Baden-Württemberg          GER  Germany West Germany      180.0
# 375             Nova Scotia          CAN                Canada      183.0
# 423         Rheinland-Pfalz          GER                 Spain      178.0
# ...                     ...          ...                   ...        ...
# 144747              Central          GHA                 Ghana        NaN
# 145371                 Utah          USA         United States        NaN
# 145461     British Columbia          CAN                Canada      185.0
# 145488      Tunapuna-Piarco          TTO   Trinidad and Tobago        NaN
# 145492  Ciudad de La Habana          CUB                  Cuba        NaN
#
#         weight_kg   died_date
# 78            NaN  1958-03-17
# 111          79.0         NaN
# 159          74.0         NaN
# 375          74.0         NaN
# 423          70.0         NaN
# ...           ...         ...
# 144747        NaN         NaN
# 145371        NaN         NaN
# 145461       75.0         NaN
# 145488        NaN         NaN
# 145492        NaN  2019-11-24
#
# [2380 rows x 10 columns]

# %%
# Other cool regex filters

# Find athletes born in cities that start with a vowel:
vowel_cities = bios[bios['born_city'].str.contains(r'^[AEIOUaeiou]', na=False)]

# Find athletes with names that contain exactly two vowels:
two_vowels = bios[bios['name'].str.contains(r'^[^AEIOUaeiou]*[AEIOUaeiou][^AEIOUaeiou]*[AEIOUaeiou][^AEIOUaeiou]*$', na=False)]

# Find athletes with names that have repeated consecutive letters (e.g., "Aaron", "Emmett"):
repeated_letters = bios[bios['name'].str.contains(r'(.)\1', na=False)]

# Find athletes with names ending in 'son' or 'sen':
son_sen_names = bios[bios['name'].str.contains(r'son$|sen$', case=False, na=False)]

# Find athletes born in a year starting with '19':
born_19xx = bios[bios['born_date'].str.contains(r'^19', na=False)]

# Find athletes with names that do not contain any vowels:
no_vowels = bios[bios['name'].str.contains(r'^[^AEIOUaeiou]*$', na=False)]

# Find athletes whose names contain a hyphen or an apostrophe:
hyphen_apostrophe = bios[bios['name'].str.contains(r"[-']", na=False)]

# Find athletes with names that start and end with the same letter:
start_end_same = bios[bios['name'].str.contains(r'^(.).*\1$', na=False, case=False)]

# Find athletes with a born_city that has exactly 7 characters:
city_seven_chars = bios[bios['born_city'].str.contains(r'^.{7}$', na=False)]

# Find athletes with names containing three or more vowels:
three_or_more_vowels = bios[bios['name'].str.contains(r'([AEIOUaeiou].*){3,}', na=False)]
# Out:
# C:\Users\Darling\AppData\Local\Temp\ipykernel_14304\237546082.py:10: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   repeated_letters = bios[bios['name'].str.contains(r'(.)\1', na=False)]
# C:\Users\Darling\AppData\Local\Temp\ipykernel_14304\237546082.py:25: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   start_end_same = bios[bios['name'].str.contains(r'^(.).*\1$', na=False, case=False)]
# C:\Users\Darling\AppData\Local\Temp\ipykernel_14304\237546082.py:31: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   three_or_more_vowels = bios[bios['name'].str.contains(r'([AEIOUaeiou].*){3,}', na=False)]

# %%
# Don't use regex search (exact match)
bios[bios['name'].str.contains('Carl|John', case=False, regex=False)]
# Out:
# Empty DataFrame
# Columns: [athlete_id, name, born_date, born_city, born_region, born_country, NOC, height_cm, weight_kg, died_date]
# Index: []

# %%
## isin method & startswith
bios[bios['born_country'].isin(["USA", "FRA", "GBR"]) & (bios['name'].str.startswith("William"))]
# Out:
#         athlete_id               name   born_date               born_city  \
# 573            575        William Dod  1867-07-18         Lower Bebington
# 1222          1229     William Rankin  1898-08-08           Kirkintilloch
# 2218          2228      William Clark  1842-01-01              Cincinnati
# 2240          2250  William Valentine  1867-10-08               Lexington
# 2745          2757     William Easton  1875-01-25                Hannibal
# ...            ...                ...         ...                     ...
# 124915      127258     William Taylor  1870-01-01                  Hoxton
# 131150      133914    William Meynard  1987-07-11  Marseille (Marseilles)
# 135474      138688   William Scammell  2002-12-01                    Bath
# 144664      148360    William Feneley  1999-07-13                 Norwich
# 145040      148752   William Flaherty  2004-05-09              Cincinnati
#
#              born_region born_country            NOC  height_cm  weight_kg  \
# 573              England          GBR  Great Britain        NaN        NaN
# 1222            Scotland          GBR         Canada      170.0       66.0
# 2218                Ohio          USA  United States        NaN        NaN
# 2240            Illinois          USA  United States        NaN        NaN
# 2745            Missouri          USA  United States        NaN        NaN
# ...                  ...          ...            ...        ...        ...
# 124915           England          GBR  Great Britain        NaN        NaN
# 131150  Bouches-du-Rhône          FRA         France      190.0       85.0
# 135474           England          GBR  Great Britain        NaN        NaN
# 144664           England          GBR  Great Britain        NaN        NaN
# 145040              Ohio          USA    Puerto Rico        NaN        NaN
#
#          died_date
# 573     1954-10-08
# 1222    1967-08-17
# 2218    1913-10-20
# 2240    1932-08-29
# 2745    1928-08-29
# ...            ...
# 124915         NaN
# 131150         NaN
# 135474         NaN
# 144664         NaN
# 145040         NaN
#
# [150 rows x 10 columns]

# %% [markdown]
# #### Query functions

# %%
bios.query('born_country == "USA" and born_city == "Atlanta" and born_date > "2000-12-16"')
# Out:
#         athlete_id          name   born_date born_city born_region  \
# 136389      139615  Annie Sommer  2004-11-12   Atlanta     Georgia
#
#        born_country     NOC  height_cm  weight_kg died_date
# 136389          USA  France        NaN        NaN       NaN

# %% [markdown]
# ## Adding / Removing Columns

# %%
coffee = pd.read_csv('./data/coffee.csv')

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
coffee['price'] = 4.99

# %%
coffee['new_price'] = np.where(coffee['Coffee Type'] =='Espresso', 3.99, 5.99)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  new_price
# 0      Monday    Espresso          25   4.99       3.99
# 1      Monday       Latte          15   4.99       5.99
# 2     Tuesday    Espresso          30   4.99       3.99
# 3     Tuesday       Latte          20   4.99       5.99
# 4   Wednesday    Espresso          35   4.99       3.99
# 5   Wednesday       Latte          25   4.99       5.99
# 6    Thursday    Espresso          40   4.99       3.99
# 7    Thursday       Latte          30   4.99       5.99
# 8      Friday    Espresso          45   4.99       3.99
# 9      Friday       Latte          35   4.99       5.99
# 10   Saturday    Espresso          45   4.99       3.99
# 11   Saturday       Latte          35   4.99       5.99
# 12     Sunday    Espresso          45   4.99       3.99
# 13     Sunday       Latte          35   4.99       5.99

# %%
coffee.drop(columns=['price'], inplace=True)

# or you can do it like this:
# coffee = coffee.drop(columns=['price'])

# %%
coffee = coffee[['Day', 'Coffee Type', 'Units Sold', 'new_price']]

# %%
coffee['revenue'] = coffee['Units Sold'] * coffee['new_price']

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  new_price  revenue
# 0      Monday    Espresso          25       3.99    99.75
# 1      Monday       Latte          15       5.99    89.85
# 2     Tuesday    Espresso          30       3.99   119.70
# 3     Tuesday       Latte          20       5.99   119.80
# 4   Wednesday    Espresso          35       3.99   139.65
# 5   Wednesday       Latte          25       5.99   149.75
# 6    Thursday    Espresso          40       3.99   159.60
# 7    Thursday       Latte          30       5.99   179.70
# 8      Friday    Espresso          45       3.99   179.55
# 9      Friday       Latte          35       5.99   209.65
# 10   Saturday    Espresso          45       3.99   179.55
# 11   Saturday       Latte          35       5.99   209.65
# 12     Sunday    Espresso          45       3.99   179.55
# 13     Sunday       Latte          35       5.99   209.65

# %%
coffee.rename(columns={'new_price': 'price'}, inplace=True)

# %%
bios_new = bios.copy()

# %%
bios_new['first_name'] = bios_new['name'].str.split(' ').str[0]

# %%
bios_new.query('first_name == "Paul"')
# Out:
#         athlete_id               name   born_date          born_city  \
# 23              24      Paul Lebreton  1875-10-19          Paris IIe
# 24              25       Paul Lecaron  1863-07-29  Neuilly-sur-Seine
# 151            152  Paul Lindpaintner  1883-05-22   München (Munich)
# 335            336     Paul Vermeiren  1963-08-27          Herentals
# 483            484         Paul Leroy  1884-01-13             Bellot
# ...            ...                ...         ...                ...
# 137954      141336       Paul Daumont  1999-09-01             Bangui
# 139414      142887    Paul Bernardoni  1997-04-18                NaN
# 139668      143145         Paul Casey  1977-07-21         Cheltenham
# 143047      146679       Paul Jacquot  1995-12-26                NaN
# 145355      149078      Paul Schommer  1992-06-06           Appleton
#
#            born_region born_country            NOC  height_cm  weight_kg  \
# 23               Paris          FRA         France        NaN        NaN
# 24      Hauts-de-Seine          FRA         France        NaN        NaN
# 151             Bayern          GER        Germany        NaN        NaN
# 335          Antwerpen          BEL        Belgium      181.0       79.0
# 483     Seine-et-Marne          FRA         France        NaN        NaN
# ...                ...          ...            ...        ...        ...
# 137954          Bangui          CAF   Burkina Faso        NaN        NaN
# 139414             NaN          NaN         France      190.0       78.0
# 139668         England          GBR  Great Britain      178.0        NaN
# 143047             NaN          NaN    Switzerland        NaN        NaN
# 145355       Wisconsin          USA  United States        NaN        NaN
#
#          died_date first_name
# 23      1960-03-31       Paul
# 24      1940-09-17       Paul
# 151     1969-04-23       Paul
# 335            NaN       Paul
# 483     1949-04-09       Paul
# ...            ...        ...
# 137954         NaN       Paul
# 139414         NaN       Paul
# 139668         NaN       Paul
# 143047         NaN       Paul
# 145355         NaN       Paul
#
# [576 rows x 11 columns]

# %%
bios_new['born_datetime'] = pd.to_datetime(bios_new['born_date'])

# %%
bios_new['born_year'] = bios_new['born_datetime'].dt.year

# %%
bios_new[['name','born_year']]
# Out:
#                          name  born_year
# 0       Jean-François Blanchy     1886.0
# 1              Arnaud Boetsch     1969.0
# 2                Jean Borotra     1898.0
# 3             Jacques Brugnon     1895.0
# 4                Albert Canet     1878.0
# ...                       ...        ...
# 145495      Polina Luchnikova     2002.0
# 145496    Valeriya Merkusheva     1999.0
# 145497        Yuliya Smirnova     1998.0
# 145498         André Foussard     1899.0
# 145499          Bill Phillips     1913.0
#
# [145500 rows x 2 columns]

# %%
bios_new.to_csv('./data/bios_new.csv', index=False)

# %%
bios['height_category'] = bios['height_cm'].apply(lambda x: 'Short' if x < 165 else ('Average' if x < 185 else 'Tall'))

# %%
def categorize_athlete(row):
    if row['height_cm'] < 175 and row['weight_kg'] < 70:
        return 'Lightweight'
    elif row['height_cm'] < 185 or row['weight_kg'] <= 80:
        return 'Middleweight'
    
    else:
        return 'Heavyweight'
    
bios['Category'] = bios.apply(categorize_athlete, axis=1)

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date height_category      Category
# 0  1960-10-02            Tall   Heavyweight
# 1         NaN         Average  Middleweight
# 2  1994-07-17         Average  Middleweight
# 3  1978-03-20         Average   Lightweight
# 4  1930-07-25            Tall   Heavyweight

# %% [markdown]
# ## Handling Null Values

# %%
coffee = pd.read_csv('./data/coffee.csv')
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.loc[[2,3], 'Units Sold'] = np.nan
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso        25.0
# 1      Monday       Latte        15.0
# 2     Tuesday    Espresso         NaN
# 3     Tuesday       Latte         NaN
# 4   Wednesday    Espresso        35.0
# 5   Wednesday       Latte        25.0
# 6    Thursday    Espresso        40.0
# 7    Thursday       Latte        30.0
# 8      Friday    Espresso        45.0
# 9      Friday       Latte        35.0
# 10   Saturday    Espresso        45.0
# 11   Saturday       Latte        35.0
# 12     Sunday    Espresso        45.0
# 13     Sunday       Latte        35.0

# %%
# Make sure to set this to your Units Sold column if you want these changes to stick
coffee['Units Sold'] = coffee['Units Sold'].fillna(coffee['Units Sold'].mean()) 
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso   25.000000
# 1      Monday       Latte   15.000000
# 2     Tuesday    Espresso   34.166667
# 3     Tuesday       Latte   34.166667
# 4   Wednesday    Espresso   35.000000
# 5   Wednesday       Latte   25.000000
# 6    Thursday    Espresso   40.000000
# 7    Thursday       Latte   30.000000
# 8      Friday    Espresso   45.000000
# 9      Friday       Latte   35.000000
# 10   Saturday    Espresso   45.000000
# 11   Saturday       Latte   35.000000
# 12     Sunday    Espresso   45.000000
# 13     Sunday       Latte   35.000000

# %%
# coffee['Units Sold'] = coffee['Units Sold'].interpolate()
coffee['Units Sold'].interpolate()
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso   25.000000
# 1      Monday       Latte   15.000000
# 2     Tuesday    Espresso   34.166667
# 3     Tuesday       Latte   34.166667
# 4   Wednesday    Espresso   35.000000
# 5   Wednesday       Latte   25.000000
# 6    Thursday    Espresso   40.000000
# 7    Thursday       Latte   30.000000
# 8      Friday    Espresso   45.000000
# 9      Friday       Latte   35.000000
# 10   Saturday    Espresso   45.000000
# 11   Saturday       Latte   35.000000
# 12     Sunday    Espresso   45.000000
# 13     Sunday       Latte   35.000000

# %%
coffee.dropna(subset=['Units Sold']) # Use inplace=True if you want to update the coffee df
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso   25.000000
# 1      Monday       Latte   15.000000
# 2     Tuesday    Espresso   34.166667
# 3     Tuesday       Latte   34.166667
# 4   Wednesday    Espresso   35.000000
# 5   Wednesday       Latte   25.000000
# 6    Thursday    Espresso   40.000000
# 7    Thursday       Latte   30.000000
# 8      Friday    Espresso   45.000000
# 9      Friday       Latte   35.000000
# 10   Saturday    Espresso   45.000000
# 11   Saturday       Latte   35.000000
# 12     Sunday    Espresso   45.000000
# 13     Sunday       Latte   35.000000

# %%
coffee[coffee['Units Sold'].notna()]
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso   25.000000
# 1      Monday       Latte   15.000000
# 2     Tuesday    Espresso   34.166667
# 3     Tuesday       Latte   34.166667
# 4   Wednesday    Espresso   35.000000
# 5   Wednesday       Latte   25.000000
# 6    Thursday    Espresso   40.000000
# 7    Thursday       Latte   30.000000
# 8      Friday    Espresso   45.000000
# 9      Friday       Latte   35.000000
# 10   Saturday    Espresso   45.000000
# 11   Saturday       Latte   35.000000
# 12     Sunday    Espresso   45.000000
# 13     Sunday       Latte   35.000000

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso   25.000000
# 1      Monday       Latte   15.000000
# 2     Tuesday    Espresso   34.166667
# 3     Tuesday       Latte   34.166667
# 4   Wednesday    Espresso   35.000000
# 5   Wednesday       Latte   25.000000
# 6    Thursday    Espresso   40.000000
# 7    Thursday       Latte   30.000000
# 8      Friday    Espresso   45.000000
# 9      Friday       Latte   35.000000
# 10   Saturday    Espresso   45.000000
# 11   Saturday       Latte   35.000000
# 12     Sunday    Espresso   45.000000
# 13     Sunday       Latte   35.000000

# %% [markdown]
# ## `skimpy` summary
# " a light weight tool that provides summary statistics about variables in data frames within the console or your interactive Python window"

# %%
from skimpy import skim

skim(results)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 308408 │ │ string      │ 7     │                                                          │
# │ │ Number of columns │ 11     │ │ float64     │ 2     │                                                          │
# │ └───────────────────┴────────┘ │ int64       │ 1     │                                                          │
# │                                │ bool        │ 1     │                                                          │
# │                                └─────────────┴───────┘                                                          │
# │                                                     number                                                      │
# │ ┏━━━━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━┳━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━━┳━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┓  │
# │ ┃ column_name    ┃ NA      ┃ NA %  ┃ mean   ┃ sd     ┃ p0    ┃ p25    ┃ p50    ┃ p75     ┃ p100    ┃ hist    ┃  │
# │ ┡━━━━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━╇━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━━╇━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━┩  │
# │ │ year           │    2601 │  0.84 │   1982 │  30.98 │  1896 │   1964 │   1992 │    2008 │    2022 │ ▁▂▂▅▇▇  │  │
# │ │ athlete_id     │       0 │     0 │  72620 │  41290 │     1 │  34410 │  73740 │  107200 │  149000 │ ▆▇▆▇▇▅  │  │
# │ │ place          │   25215 │  8.18 │   16.1 │  19.32 │     1 │      5 │      9 │      20 │     185 │   ▇▁    │  │
# │ └────────────────┴─────────┴───────┴────────┴────────┴───────┴────────┴────────┴─────────┴─────────┴─────────┘  │
# │                                                      bool                                                       │
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┓  │
# │ ┃ column_name                       ┃ true              ┃ true rate                    ┃ hist                ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━┩  │
# │ │ tied                              │             45940 │                         0.15 │       ▇    ▁        │  │
# │ └───────────────────────────────────┴───────────────────┴──────────────────────────────┴─────────────────────┘  │
# │                                                     string                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┓  │
# │ ┃ column_name             ┃ NA            ┃ NA %        ┃ words per row              ┃ total words           ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━┩  │
# │ │ type                    │          2601 │        0.84 │                       0.99 │                305807 │  │
# │ │ discipline              │             1 │           0 │                          2 │                610211 │  │
# │ │ event                   │             0 │           0 │                        4.2 │               1303323 │  │
# │ │ as                      │             0 │           0 │                        2.1 │                634574 │  │
# │ │ noc                     │             1 │           0 │                          1 │                308407 │  │
# │ │ team                    │        186694 │       60.53 │                       0.62 │                190405 │  │
# │ │ medal                   │        264269 │       85.69 │                       0.14 │                 44139 │  │
# │ └─────────────────────────┴───────────────┴─────────────┴────────────────────────────┴───────────────────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯
